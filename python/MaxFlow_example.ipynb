# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import load_graph, draw_graph, compute_max_flow

# %%
graph_path = '../graph/graph_def.graphml'
graph = load_graph(graph_path)
draw_graph(graph)

# %%
max_flow, final_graph, steps_graph = compute_max_flow(graph=graph, steps=True)
for g in steps_graph:
    draw_graph(g, flow=True)

# %%
draw_graph(final_graph, flow=True)

# %%
print('The max flow is ', max_flow, '.', sep='')
# Out:
# The max flow is 6.0.
